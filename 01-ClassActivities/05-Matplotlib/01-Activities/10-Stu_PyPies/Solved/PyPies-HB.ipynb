# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pies = ["Apple", "Pumpkin", "Chocolate Creme", "Cherry", "Apple Crumb", 
        "Pecan", "Lemon Meringue", "Blueberry", "Key Lime", "Peach"]
pie_votes = [47,37,32,27,25,24,24,21,18,16]
pie_type = ["Fruit", "Custard/Creme", "Custard/Creme", "Fruit", "Fruit", 
           "Custard/Creme", "Custard/Creme", "Fruit", "Custard/Creme", "Fruit"]

# %%
df = pd.DataFrame({'pies': pies, 'votes': pie_votes, 'types': pie_type})
df
# Out:
#               pies  votes          types
# 0            Apple     47          Fruit
# 1          Pumpkin     37  Custard/Creme
# 2  Chocolate Creme     32  Custard/Creme
# 3           Cherry     27          Fruit
# 4      Apple Crumb     25          Fruit
# 5            Pecan     24  Custard/Creme
# 6   Lemon Meringue     24  Custard/Creme
# 7        Blueberry     21          Fruit
# 8         Key Lime     18  Custard/Creme
# 9            Peach     16          Fruit

# %%
dfg = df.groupby(df['types'])
dfg['votes'].sum()
# Out:
# types
# Custard/Creme    135
# Fruit            136
# Name: votes, dtype: int64

# %%
pie_data = pd.DataFrame(dfg['votes'].sum())
pie_data.reset_index()
# Out:
#            types  votes
# 0  Custard/Creme    135
# 1          Fruit    136

# %%
# Tell matplotlib to create a pie chart based upon the above data
plt.pie(pie_data['votes'], labels=pie_data.iloc[:,0], autopct="%1.1f%%", 
        startangle=90)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Save an image of our chart and print the final product to the screen
plt.savefig("../Images/PyPies-HB.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-3756d2ecdc04> in <module>
#       1 pltpie = plt.pie(dfg['votes'].sum())
# ----> 2 pltpie.show()
#
# AttributeError: 'tuple' object has no attribute 'show'
