# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
import pandas as pd

csv_path = "Resources/EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)
eclipse_df.head()
# Out:
#    Bug\nID Product Component Assignee    Status Resolution  \
# 0     3638     JDT        UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT        UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ... Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                   3
# 1   Martin Aeschlimann        Eclipse  ...                   5
# 2   Martin Aeschlimann        Eclipse  ...                   3
# 3   Martin Aeschlimann        Eclipse  ...                  10
# 4   Martin Aeschlimann        Eclipse  ...                   5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
# Finding the average number of comments per bug
bugID = eclipse_df.groupby("Bug\nID")

average_comments = eclipse_df["Number of\nComments"].mean()
print(f"There are {average_comments} comments per bug on average")
# Out:
# There are 8.75 comments per bug on average

# %%
# Grouping the DataFrame by "Assignee"
assignee_group = eclipse_df.groupby("Assignee")

# Count how many of each component Assignees worked on and create DataFrame
assignee_work_df = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work_df.head()
# Out:
#                                 Component
# Assignee       Component
# Aaron_Ferguson UI                      10
# Adam_Schlegel  UI                       7
# ChrisAustin    User Assistance          3
# Claude_Knaus   UI                      31
#                Text                     7

# %%
# Rename the "Component" column to "Component Bug Count"
assignee_work_df = assignee_work_df.rename(
    columns={"Component": "Component Bug Count"})
assignee_work_df.head()
# Out:
#                                 Component Bug Count
# Assignee       Component
# Aaron_Ferguson UI                                10
# Adam_Schlegel  UI                                 7
# ChrisAustin    User Assistance                    3
# Claude_Knaus   UI                                31
#                Text                               7

# %%
# Find the percentage of bugs overall fixed by each Assignee
total_bugs = eclipse_df["Bug\nID"].count()
bugs_per_user = assignee_group["Assignee"].count()

user_bug_percent_df = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent_df.head()
# Out:
#                 Assignee
# Assignee
# Aaron_Ferguson      0.10
# Adam_Schlegel       0.07
# ChrisAustin         0.03
# Claude_Knaus        0.38
# Curtis_Windatt      0.06

# %%
# Reset the index of "assignee_group" so that "Assignee" and "Component" are columns
assignee_work_df = assignee_work_df.reset_index()
assignee_work_df
# Out:
#             Assignee                                 Component  \
# 0     Aaron_Ferguson                                        UI
# 1      Adam_Schlegel                                        UI
# 2        ChrisAustin                           User Assistance
# 3       Claude_Knaus                                        UI
# 4       Claude_Knaus                                      Text
# ..               ...                                       ...
# 345         valentam                                   Compare
# 346  veronika_irvine                                       SWT
# 347    wassim.melhem                                        UI
# 348    wassim.melhem  Update  (deprecated - use RT>Equinox>p2)
# 349         zhiyongl                                       CVS
#
#      Component Bug Count
# 0                     10
# 1                      7
# 2                      3
# 3                     31
# 4                      7
# ..                   ...
# 345                    6
# 346                    2
# 347                    3
# 348                    1
# 349                    1
#
# [350 rows x 3 columns]

# %%
# Merge the "Percent of Total Bugs Assigned" into the DataFrame
assignee_work_df = assignee_work_df.merge(user_bug_percent_df, on="Assignee")
assignee_work_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-a7e2c54dfc89> in <module>
#       1 # Merge the "Percent of Total Bugs Assigned" into the DataFrame
# ----> 2 assignee_work_df = assignee_work_df.merge(user_bug_percent_df, on="Assignee")
#       3 assignee_work_df.head()
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1685
#    1686         if self._is_label_reference(key, axis=axis):
# -> 1687             self._check_label_or_level_ambiguity(key, axis=axis)
#    1688             values = self.xs(key, axis=other_axes[0])._values
#    1689         elif self._is_level_reference(key, axis=axis):
#
# C:\Users\Anaconda\lib\site-packages\pandas\core\generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1645                 f"{label_article} {label_type} label, which is ambiguous."
#    1646             )
# -> 1647             raise ValueError(msg)
#    1648
#    1649     def _get_label_or_level_values(self, key: str, axis: int = 0) -> np.ndarray:
#
# ValueError: 'Assignee' is both an index level and a column label, which is ambiguous.
