# %%
# Import Dependencies
import pandas as pd
import os

# %%
# look for missing values
crimeDF.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
# Reference the file where the CSV is located
resource = os.path.join("Resources","crime_incident_data2017.csv")
# Import the data into a Pandas DataFrame
crimeRawDF = pd.read_csv(resource)
crimeDF = pd.read_csv(resource)
crimeDF.head(10)
# Out:
#                         Address  Case Number Crime Against     Neighborhood  \
# 0                           NaN  17-X4762181        Person              NaN
# 1                           NaN  17-X4757824      Property       Centennial
# 2      200 BLOCK OF SE 78TH AVE    17-900367      Property       Montavilla
# 3                           NaN  17-X4748982      Property  Southwest Hills
# 4                           NaN  17-X4748982      Property  Southwest Hills
# 5  5400 BLOCK OF NE MALLORY AVE    17-900129      Property             King
# 6     5000 BLOCK OF NE 19TH AVE    17-901079      Property           Vernon
# 7     5000 BLOCK OF NE 19TH AVE    17-901079      Property           Vernon
# 8     12000 BLOCK OF SE PINE ST    17-900253      Property        Hazelwood
# 9     12000 BLOCK OF SE PINE ST    17-900253      Property        Hazelwood
#
#    Number of Records Occur Date Occur Month Year  Occur Time  \
# 0                  1     1/1/96           1/1/96         800
# ...

# %%
# drop null rows
crimeDF = crimeDF.dropna(how='any')

# %%
# verify counts
crimeDF.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
crimeDF["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       6947
# Motor Vehicle Theft                            4689
# All Other Larceny                              4558
# Vandalism                                      3863
# Burglary                                       2824
# Shoplifting                                    2259
# Identity Theft                                 1794
# Simple Assault                                 1216
# Drug/Narcotic Violations                       1095
# Theft of Motor Vehicle Parts or Accessories    1073
# Intimidation                                    900
# Theft From Building                             895
# False Pretenses/Swindle/Confidence Game         870
# Aggravated Assault                              839
# Robbery                                         608
# Counterfeiting/Forgery                          448
# Weapons Law Violations                          266
# Credit Card/ATM Fraud                           226
# ...

# %%
# Combine similar offenses
crimeDF = crimeDF.replace(
    {'Burglary': 'Burglary','Stolen Property Offenses':'Burglary', 'Theft From Building': 'Burglary'})
crimeDF.columns
# Out:
# Index(['Address', 'Case Number', 'Crime Against', 'Neighborhood',
#        'Number of Records', 'Occur Date', 'Occur Month Year', 'Occur Time',
#        'Offense Category', 'Offense Count', 'Offense Type', 'Open Data Lat',
#        'Open Data Lon', 'Open Data X', 'Open Data Y', 'Report Date',
#        'Report Month Year'],
#       dtype='object')

# %%
# Check to see if you comnbined similar offenses correctly in "Offense Type".
crimeDF["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       6947
# Motor Vehicle Theft                            4689
# All Other Larceny                              4558
# Vandalism                                      3863
# Burglary                                       3776
# Shoplifting                                    2259
# Identity Theft                                 1794
# Simple Assault                                 1216
# Drug/Narcotic Violations                       1095
# Theft of Motor Vehicle Parts or Accessories    1073
# Intimidation                                    900
# False Pretenses/Swindle/Confidence Game         870
# Aggravated Assault                              839
# Robbery                                         608
# Counterfeiting/Forgery                          448
# Weapons Law Violations                          266
# Credit Card/ATM Fraud                           226
# Arson                                           200
# ...

# %%
# Compare numbers to raw data
crimeRawDF["Offense Type"].value_counts()
# Out:
# Theft From Motor Vehicle                       7256
# All Other Larceny                              4900
# Motor Vehicle Theft                            4799
# Vandalism                                      4189
# Burglary                                       2901
# Simple Assault                                 2453
# Shoplifting                                    2332
# Identity Theft                                 2040
# Intimidation                                   1678
# Aggravated Assault                             1217
# Drug/Narcotic Violations                       1142
# Theft of Motor Vehicle Parts or Accessories    1107
# False Pretenses/Swindle/Confidence Game         972
# Theft From Building                             961
# Robbery                                         680
# Counterfeiting/Forgery                          470
# Weapons Law Violations                          298
# Credit Card/ATM Fraud                           264
# ...

# %%
# Create a new DataFrame that looks into a specific neighborhood
crimeDF["Neighborhood"].value_counts()
downtownCrime = crimeDF.loc[crimeDF["Neighborhood"] == "Downtown",:]
downtownCrime.head()
# Out:
#                            Address Case Number Crime Against Neighborhood  \
# 32          500 BLOCK OF SW OAK ST   17-900051      Property     Downtown
# 33  1300 BLOCK OF SW WASHINGTON ST     17-4490      Property     Downtown
# 63        1100 BLOCK OF SW 2ND AVE    17-27849      Property     Downtown
# 86   1000 BLOCK OF SW JEFFERSON ST   17-900855      Property     Downtown
# 95        1100 BLOCK OF SW 2ND AVE     17-5712      Property     Downtown
#
#     Number of Records Occur Date Occur Month Year  Occur Time  \
# 32                  1    1/31/16           1/1/16        2300
# 33                  1     1/3/16           1/1/16        1900
# 63                  1     6/1/16           6/1/16           1
# 86                  1    9/28/16           9/1/16        2000
# 95                  1   10/20/16          10/1/16        1200
#
#        Offense Category  Offense Count              Offense Type  \
# 32     Larceny Offenses              1  Theft From Motor Vehicle
# ...
